# %%
# importing the necessary libraries
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.datasets import fetch_lfw_people
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.21.0

# %%
# loading LFW dataset - keeping only people with at least 70 images
lfw = fetch_lfw_people(min_faces_per_person=70, resize=0.4)

print("Dataset shape:", lfw.images.shape)
print("Number of classes (people):", lfw.target_names.shape[0])
print("People in dataset:", lfw.target_names)
# Out:
# Dataset shape: (1288, 50, 37)
# Number of classes (people): 7
# People in dataset: ['Ariel Sharon' 'Colin Powell' 'Donald Rumsfeld' 'George W Bush'
#  'Gerhard Schroeder' 'Hugo Chavez' 'Tony Blair']

# %%
# checking how many images each person has
print("Number of images per person:")
for i, name in enumerate(lfw.target_names):
    count = np.sum(lfw.target == i)
    print(f"  {name}: {count} images")

# visualizing some sample faces
plt.figure(figsize=(12, 8))
for i in range(14):
    plt.subplot(2, 7, i+1)
    plt.imshow(lfw.images[i * 90], cmap='gray')
    plt.title(lfw.target_names[lfw.target[i * 90]].split()[-1], fontsize=9)
    plt.xticks([])
    plt.yticks([])
plt.suptitle("Sample Faces from LFW Dataset", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Number of images per person:
#   Ariel Sharon: 77 images
#   Colin Powell: 236 images
#   Donald Rumsfeld: 121 images
#   George W Bush: 530 images
#   Gerhard Schroeder: 109 images
#   Hugo Chavez: 71 images
#   Tony Blair: 144 images

# %%
# preprocessing the data
x = lfw.images
y = lfw.target

# sklearn already gives pixel values between 0 and 1, so no need to divide by 255
print("Pixel range - Min:", x.min(), "Max:", x.max())

# adding channel dimension for CNN (grayscale = 1 channel)
x = x.reshape(-1, 50, 37, 1)

# splitting into train and test (80-20 split)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

print("Training data shape:", x_train.shape)
print("Test data shape:", x_test.shape)
# Out:
# Pixel range - Min: 0.0 Max: 1.0
# Training data shape: (1030, 50, 37, 1)
# Test data shape: (258, 50, 37, 1)

# %%
# building the CNN model for face recognition
model = models.Sequential([
    # first conv block - 32 filters
    layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(50, 37, 1)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # second conv block - 64 filters
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # third conv block - 128 filters
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # dense layers
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),

    # output layer - 7 people so 7 neurons with softmax
    layers.Dense(7, activation='softmax')
])

model.summary()
# Out:
# /opt/anaconda3/envs/lfw_env/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 50, 37, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 50, 37, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 25, 18, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 25, 18, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 25, 18, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 25, 18, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 9, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 9, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 9, 128)     │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 12, 9, 128)     │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       393,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 487,815 (1.86 MB)
#  Trainable params: 487,367 (1.86 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# data augmentation - important since we have limited training data
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1
)
datagen.fit(x_train)

# compiling with adam optimizer
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# callbacks - reduce lr when accuracy plateaus and early stopping
lr_reducer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=8, min_lr=1e-6, verbose=1, mode='max')
early_stop = EarlyStopping(monitor='val_accuracy', patience=20, restore_best_weights=True, verbose=1, mode='max')

# training with data augmentation
history = model.fit(datagen.flow(x_train, y_train, batch_size=32),
                    epochs=80,
                    validation_data=(x_test, y_test),
                    callbacks=[lr_reducer, early_stop])
# Out:
# Epoch 1/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.3194 - loss: 2.5351 - val_accuracy: 0.0543 - val_loss: 4.5020 - learning_rate: 0.0010
# Epoch 2/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.3583 - loss: 1.8166 - val_accuracy: 0.0543 - val_loss: 7.6772 - learning_rate: 0.0010
# Epoch 3/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.4175 - loss: 1.7233 - val_accuracy: 0.0543 - val_loss: 8.3917 - learning_rate: 0.0010
# Epoch 4/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4117 - loss: 1.6729 - val_accuracy: 0.0543 - val_loss: 8.9245 - learning_rate: 0.0010
# Epoch 5/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.4340 - loss: 1.6045 - val_accuracy: 0.0930 - val_loss: 5.8632 - learning_rate: 0.0010
# Epoch 6/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4437 - loss: 1.5304 - val_accuracy: 0.0891 - val_loss: 5.4788 - learning_rate: 0.0010
# Epoch 7/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.4718 - loss: 1.5213 - val_accuracy: 0.1705 - val_loss: 4.6484 - learning_rate: 0.0010
# Epoch 8/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.4845 - loss: 1.4541 - val_accuracy: 0.1977 - val_loss: 3.4754 - learning_rate: 0.0010
# Epoch 9/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4981 - loss: 1.4257 - val_accuracy: 0.3605 - val_loss: 2.7349 - learning_rate: 0.0010
# Epoch 10/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.5068 - loss: 1.3628 - val_accuracy: 0.4225 - val_loss: 2.8482 - learning_rate: 0.0010
# Epoch 11/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.5243 - loss: 1.3316 - val_accuracy: 0.4767 - val_loss: 2.2302 - learning_rate: 0.0010
# Epoch 12/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.5223 - loss: 1.2777 - val_accuracy: 0.4651 - val_loss: 2.6503 - learning_rate: 0.0010
# Epoch 13/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5602 - loss: 1.2583 - val_accuracy: 0.4767 - val_loss: 2.4137 - learning_rate: 0.0010
# Epoch 14/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5592 - loss: 1.2442 - val_accuracy: 0.4884 - val_loss: 2.2470 - learning_rate: 0.0010
# Epoch 15/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5777 - loss: 1.1656 - val_accuracy: 0.4380 - val_loss: 2.4910 - learning_rate: 0.0010
# Epoch 16/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5864 - loss: 1.1457 - val_accuracy: 0.4729 - val_loss: 1.9419 - learning_rate: 0.0010
# Epoch 17/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5981 - loss: 1.1173 - val_accuracy: 0.6008 - val_loss: 1.2318 - learning_rate: 0.0010
# Epoch 18/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5854 - loss: 1.1191 - val_accuracy: 0.5969 - val_loss: 1.0565 - learning_rate: 0.0010
# Epoch 19/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.6097 - loss: 1.0440 - val_accuracy: 0.3178 - val_loss: 2.4636 - learning_rate: 0.0010
# Epoch 20/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6165 - loss: 0.9938 - val_accuracy: 0.6705 - val_loss: 0.8650 - learning_rate: 0.0010
# Epoch 21/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.6379 - loss: 1.0113 - val_accuracy: 0.6705 - val_loss: 0.8777 - learning_rate: 0.0010
# Epoch 22/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6204 - loss: 1.0496 - val_accuracy: 0.7093 - val_loss: 0.9504 - learning_rate: 0.0010
# Epoch 23/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6388 - loss: 0.9782 - val_accuracy: 0.7093 - val_loss: 0.8126 - learning_rate: 0.0010
# Epoch 24/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6515 - loss: 0.9845 - val_accuracy: 0.5465 - val_loss: 1.6164 - learning_rate: 0.0010
# Epoch 25/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6806 - loss: 0.8772 - val_accuracy: 0.3333 - val_loss: 2.6012 - learning_rate: 0.0010
# Epoch 26/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.6883 - loss: 0.8685 - val_accuracy: 0.3992 - val_loss: 2.1525 - learning_rate: 0.0010
# Epoch 27/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6709 - loss: 0.9262 - val_accuracy: 0.8178 - val_loss: 0.5381 - learning_rate: 0.0010
# Epoch 28/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6864 - loss: 0.8529 - val_accuracy: 0.8256 - val_loss: 0.5276 - learning_rate: 0.0010
# Epoch 29/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.7058 - loss: 0.7982 - val_accuracy: 0.7287 - val_loss: 0.7972 - learning_rate: 0.0010
# Epoch 30/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.7233 - loss: 0.7916 - val_accuracy: 0.7287 - val_loss: 0.8398 - learning_rate: 0.0010
# Epoch 31/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.7194 - loss: 0.7674 - val_accuracy: 0.8488 - val_loss: 0.4133 - learning_rate: 0.0010
# Epoch 32/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7068 - loss: 0.8295 - val_accuracy: 0.7946 - val_loss: 0.5311 - learning_rate: 0.0010
# Epoch 33/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.7291 - loss: 0.7343 - val_accuracy: 0.6822 - val_loss: 0.8537 - learning_rate: 0.0010
# Epoch 34/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7262 - loss: 0.7993 - val_accuracy: 0.7442 - val_loss: 0.7325 - learning_rate: 0.0010
# Epoch 35/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7417 - loss: 0.7114 - val_accuracy: 0.8023 - val_loss: 0.5173 - learning_rate: 0.0010
# Epoch 36/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.7175 - loss: 0.7519 - val_accuracy: 0.7558 - val_loss: 0.7108 - learning_rate: 0.0010
# Epoch 37/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7184 - loss: 0.7477 - val_accuracy: 0.8721 - val_loss: 0.4026 - learning_rate: 0.0010
# Epoch 38/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7427 - loss: 0.7096 - val_accuracy: 0.7752 - val_loss: 0.6982 - learning_rate: 0.0010
# Epoch 39/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7146 - loss: 0.7663 - val_accuracy: 0.7519 - val_loss: 0.6817 - learning_rate: 0.0010
# Epoch 40/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.7893 - loss: 0.6084 - val_accuracy: 0.8992 - val_loss: 0.3537 - learning_rate: 0.0010
# Epoch 41/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7534 - loss: 0.6670 - val_accuracy: 0.6279 - val_loss: 1.1063 - learning_rate: 0.0010
# Epoch 42/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7748 - loss: 0.6652 - val_accuracy: 0.8372 - val_loss: 0.4708 - learning_rate: 0.0010
# Epoch 43/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7971 - loss: 0.5920 - val_accuracy: 0.9070 - val_loss: 0.2508 - learning_rate: 0.0010
# Epoch 44/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.7971 - loss: 0.5812 - val_accuracy: 0.8953 - val_loss: 0.2544 - learning_rate: 0.0010
# Epoch 45/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.8010 - loss: 0.5613 - val_accuracy: 0.8837 - val_loss: 0.3536 - learning_rate: 0.0010
# Epoch 46/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7699 - loss: 0.6488 - val_accuracy: 0.9109 - val_loss: 0.3000 - learning_rate: 0.0010
# Epoch 47/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.7738 - loss: 0.6257 - val_accuracy: 0.9031 - val_loss: 0.2934 - learning_rate: 0.0010
# Epoch 48/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8078 - loss: 0.5759 - val_accuracy: 0.8915 - val_loss: 0.3341 - learning_rate: 0.0010
# Epoch 49/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7864 - loss: 0.5850 - val_accuracy: 0.8992 - val_loss: 0.3872 - learning_rate: 0.0010
# Epoch 50/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7748 - loss: 0.6645 - val_accuracy: 0.8798 - val_loss: 0.4691 - learning_rate: 0.0010
# Epoch 51/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.7709 - loss: 0.6108 - val_accuracy: 0.9147 - val_loss: 0.2811 - learning_rate: 0.0010
# Epoch 52/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.7767 - loss: 0.5806 - val_accuracy: 0.9264 - val_loss: 0.2404 - learning_rate: 0.0010
# Epoch 53/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7961 - loss: 0.5765 - val_accuracy: 0.9186 - val_loss: 0.2998 - learning_rate: 0.0010
# Epoch 54/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.8039 - loss: 0.5485 - val_accuracy: 0.6395 - val_loss: 1.4024 - learning_rate: 0.0010
# Epoch 55/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8029 - loss: 0.5539 - val_accuracy: 0.7674 - val_loss: 0.6529 - learning_rate: 0.0010
# Epoch 56/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8272 - loss: 0.5157 - val_accuracy: 0.6047 - val_loss: 1.2503 - learning_rate: 0.0010
# Epoch 57/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.7981 - loss: 0.5546 - val_accuracy: 0.9186 - val_loss: 0.2209 - learning_rate: 0.0010
# Epoch 58/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8330 - loss: 0.4677 - val_accuracy: 0.7403 - val_loss: 0.8638 - learning_rate: 0.0010
# Epoch 59/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.8223 - loss: 0.5057 - val_accuracy: 0.9070 - val_loss: 0.2249 - learning_rate: 0.0010
# Epoch 60/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8573 - loss: 0.4203
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.8495 - loss: 0.4516 - val_accuracy: 0.9186 - val_loss: 0.2245 - learning_rate: 0.0010
# Epoch 61/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.8476 - loss: 0.4315 - val_accuracy: 0.9419 - val_loss: 0.1806 - learning_rate: 5.0000e-04
# Epoch 62/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8340 - loss: 0.4688 - val_accuracy: 0.9690 - val_loss: 0.1296 - learning_rate: 5.0000e-04
# Epoch 63/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8524 - loss: 0.4334 - val_accuracy: 0.9341 - val_loss: 0.2409 - learning_rate: 5.0000e-04
# Epoch 64/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8602 - loss: 0.4158 - val_accuracy: 0.9496 - val_loss: 0.1629 - learning_rate: 5.0000e-04
# Epoch 65/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.8534 - loss: 0.4002 - val_accuracy: 0.9535 - val_loss: 0.1651 - learning_rate: 5.0000e-04
# Epoch 66/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8602 - loss: 0.4153 - val_accuracy: 0.9729 - val_loss: 0.1101 - learning_rate: 5.0000e-04
# Epoch 67/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.8495 - loss: 0.4286 - val_accuracy: 0.9341 - val_loss: 0.2136 - learning_rate: 5.0000e-04
# Epoch 68/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.8505 - loss: 0.4311 - val_accuracy: 0.9535 - val_loss: 0.1307 - learning_rate: 5.0000e-04
# Epoch 69/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.8728 - loss: 0.3580 - val_accuracy: 0.9574 - val_loss: 0.1294 - learning_rate: 5.0000e-04
# Epoch 70/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.8718 - loss: 0.3864 - val_accuracy: 0.9535 - val_loss: 0.1398 - learning_rate: 5.0000e-04
# Epoch 71/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8408 - loss: 0.4303 - val_accuracy: 0.9264 - val_loss: 0.1909 - learning_rate: 5.0000e-04
# Epoch 72/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8883 - loss: 0.3519 - val_accuracy: 0.9612 - val_loss: 0.1163 - learning_rate: 5.0000e-04
# Epoch 73/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8757 - loss: 0.3728 - val_accuracy: 0.9457 - val_loss: 0.1561 - learning_rate: 5.0000e-04
# Epoch 74/80
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8547 - loss: 0.3790
# Epoch 74: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8563 - loss: 0.4032 - val_accuracy: 0.9457 - val_loss: 0.1535 - learning_rate: 5.0000e-04
# Epoch 75/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.8699 - loss: 0.3592 - val_accuracy: 0.9690 - val_loss: 0.1076 - learning_rate: 2.5000e-04
# Epoch 76/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8748 - loss: 0.3520 - val_accuracy: 0.9496 - val_loss: 0.1699 - learning_rate: 2.5000e-04
# Epoch 77/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8748 - loss: 0.3858 - val_accuracy: 0.9535 - val_loss: 0.1466 - learning_rate: 2.5000e-04
# Epoch 78/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.8981 - loss: 0.3125 - val_accuracy: 0.9535 - val_loss: 0.1283 - learning_rate: 2.5000e-04
# Epoch 79/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.8883 - loss: 0.3478 - val_accuracy: 0.9767 - val_loss: 0.1064 - learning_rate: 2.5000e-04
# Epoch 80/80
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8670 - loss: 0.3850 - val_accuracy: 0.9651 - val_loss: 0.1176 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 79.

# %%
# plotting accuracy and loss curves to check for overfitting
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(history.history['accuracy'], label='Training Accuracy')
ax1.plot(history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_title('Training vs Validation Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()
ax1.grid(True)

ax2.plot(history.history['loss'], label='Training Loss')
ax2.plot(history.history['val_loss'], label='Validation Loss')
ax2.set_title('Training vs Validation Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

print("\nFinal Training Accuracy: {:.2f}%".format(history.history['accuracy'][-1] * 100))
print("Final Validation Accuracy: {:.2f}%".format(history.history['val_accuracy'][-1] * 100))

if history.history['val_accuracy'][-1] >= history.history['accuracy'][-1]:
    print("\n✅ No overfitting detected - validation accuracy is >= training accuracy")
else:
    gap = history.history['accuracy'][-1] - history.history['val_accuracy'][-1]
    if gap < 0.05:
        print("\n✅ No significant overfitting - gap is only {:.2f}%".format(gap * 100))
    else:
        print("\n⚠️ Possible overfitting - gap is {:.2f}%".format(gap * 100))
# Out:
# Final Training Accuracy: 86.70%
# Final Validation Accuracy: 96.51%
#
# ✅ No overfitting detected - validation accuracy is >= training accuracy

# %%
# evaluating on test data
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=1)
print("\nTest Accuracy: {:.2f}%".format(test_accuracy * 100))
print("Test Loss: {:.4f}".format(test_loss))

# visualizing some predictions
predictions = model.predict(x_test[:15])

plt.figure(figsize=(15, 9))
for i in range(15):
    plt.subplot(3, 5, i+1)
    plt.imshow(x_test[i].reshape(50, 37), cmap='gray')
    predicted = lfw.target_names[np.argmax(predictions[i])].split()[-1]
    actual = lfw.target_names[y_test[i]].split()[-1]
    color = 'green' if predicted == actual else 'red'
    plt.xlabel(f"Pred: {predicted}\nActual: {actual}", color=color, fontsize=8)
    plt.xticks([])
    plt.yticks([])
plt.suptitle("Face Recognition Predictions (Green = Correct, Red = Wrong)", fontsize=13)
plt.tight_layout()
plt.show()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9767 - loss: 0.1064
#
# Test Accuracy: 97.67%
# Test Loss: 0.1064
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step

# %%
# classification report and confusion matrix
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

y_pred = np.argmax(model.predict(x_test), axis=1)
short_names = [name.split()[-1] for name in lfw.target_names]

print("Classification Report:\n")
print(classification_report(y_test, y_pred, target_names=short_names))

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=short_names, yticklabels=short_names)
plt.title('Confusion Matrix - LFW Face Recognition')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print("\n✅ Final Test Accuracy: {:.2f}% (Target was 90%)".format(test_accuracy * 100))
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       Sharon       1.00      1.00      1.00        16
#       Powell       1.00      1.00      1.00        47
#     Rumsfeld       1.00      0.96      0.98        24
#         Bush       0.97      0.99      0.98       106
#    Schroeder       0.95      0.95      0.95        22
#       Chavez       1.00      0.93      0.96        14
#        Blair       0.93      0.93      0.93        29
#
#     accuracy                           0.98       258
#    macro avg       0.98      0.97      0.97       258
# weighted avg       0.98      0.98      0.98       258
# ✅ Final Test Accuracy: 97.67% (Target was 90%)
